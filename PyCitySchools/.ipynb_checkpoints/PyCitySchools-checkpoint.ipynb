# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
# File to Load (Remember to Change These)
school_data_to_load = "../Resources/schools_complete.csv"
student_data_to_load = "../Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
school_data
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
student_data
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# ...

# %%
# Show initial data table
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
# Show data table's column names
school_data_complete.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %%
# DISTRICT SUMMARY - Total Schools
total_schools = school_data_complete.school_name.nunique()
total_schools
# Out:
# 15

# %%
# DISTRICT SUMMARY - Total Students
total_students = school_data_complete.shape[0]
total_students
# Out:
# 39170

# %%
# DISTRICT SUMMARY - Total Budget
grouped_school = school_data.groupby(['type'])
grouped_school.count().head()
grouped_by_schools = school_data["budget"].sum()
grouped_by_schools
# Out:
# 24649428

# %%
# DISTRICT SUMMARY - Average Math Score
average_math = school_data_complete["math_score"].mean()
average_math
# Out:
# 78.98537145774827

# %%
# DISTRICT SUMMARY - Average Reading Score
average_reading = school_data_complete["reading_score"].mean()
average_reading
# Out:
# 81.87784018381414

# %%
# DISTRICT SUMMARY - Passing Math Score
passing_math = school_data_complete.loc[school_data_complete["math_score"] >= 70]
total_passing_math = passing_math.shape[0]
total_passing_math
# Out:
# 29370

# %%
# DISTRICT SUMARRY - Passing Reading Score
passing_reading = school_data_complete.loc[school_data_complete["reading_score"] >= 70]
total_passing_reading = passing_reading.shape[0]
total_passing_reading
# Out:
# 33610

# %%
# DISTRICT SUMMARY - Percentage Passing Math
percent_math = (29730/39170) * 100
percent_math
# Out:
# 75.89992341077355

# %%
# DISTRICT SUMMARY - Percentage Passing Reading
percent_reading = (33610/39170) * 100
percent_reading
# Out:
# 85.80546336482001

# %%
# DISTRICT SUMMARY - Passing Both
passing_both = school_data_complete.loc[(school_data_complete["math_score"] >= 70) & (school_data_complete["reading_score"] >= 70)]
total_passing_both = passing_both.shape[0]
total_passing_both
# Out:
# 25528

# %%
# DISTRICT SUMMARY - Percentage Passing Both
percent_both = (25528/39170) * 100
percent_both
# Out:
# 65.17232575950983

# %%
# DISTRICT SUMMARY - Dataframe
summary_df = pd.DataFrame({"Total Schools": [total_schools],
                              "Total Students": total_students,
                               "Total Budget" : grouped_by_schools,
                              "Average Math Score": average_math,
                              "Average Reading Score": average_reading, "% Passing Math": percent_math, "% Passing Reading": percent_reading, "% Overall Passing": percent_both})
summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       75.899923          85.805463          65.172326

# %%
# SCHOOL SUMMARY
grouped_schools = school_data_complete.groupby(['school_name'])
print(grouped_schools)
grouped_schools.count().head(15)
# Out:
# ...
#                        Student ID  student_name  gender  grade  reading_score  \
# school_name
# Bailey High School           4976          4976    4976   4976           4976
# Cabrera High School          1858          1858    1858   1858           1858
# Figueroa High School         2949          2949    2949   2949           2949
# Ford High School             2739          2739    2739   2739           2739
# Griffin High School          1468          1468    1468   1468           1468
# Hernandez High School        4635          4635    4635   4635           4635
# Holden High School            427           427     427    427            427
# Huang High School            2917          2917    2917   2917           2917
# Johnson High School          4761          4761    4761   4761           4761
# Pena High School              962           962     962    962            962
# Rodriguez High School        3999          3999    3999   3999           3999
# ...

# %%
# SCHOOL SUMMARY - Total Students
total_students = grouped_schools.count()["size"]
total_students
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: size, dtype: int64

# %%
# SCHOOL SUMMARY - School Type
school_type = ['District', 'Charter', 'District', 'District', 'Charter', 'District', 'Charter', 'District', 'District', 'Charter', 'District', 'Charter', 'Charter', 'Charter', 'Charter']

# %%
# SCHOOL SUMMARY - Total School Budget
school_budget = school_data["budget"]
school_budget
# Out:
# 0     1910635
# 1     1884411
# 2     1056600
# 3     3022020
# 4      917500
# 5     1319574
# 6     1081356
# 7     3124928
# 8      248087
# 9      585858
# 10    1049400
# 11    2547363
# 12    3094650
# 13    1763916
# 14    1043130
# Name: budget, dtype: int64

# %%
# SCHOOL SUMMARY - Total School Budget
budget = ['$3124928', '$1081356', '$1884411', '$1763916', '917500', '$3022020', '$248087', '$1910635', '$3094650', '$585858', '$2547363', '$1056600', '$1043130', '$1319574', '$1049400']

# %%
# SCHOOL SUMMARY - Per Student Budget
per_student = ['$628', '$582', '$639', '$644', '$625', '$652', '$581', '$655', '$650', '$609', '$637', '$600', '$638', '$578', '$583']

# %%
# SCHOOL SUMMARY - Average Math Score
average_math = grouped_schools["math_score"].mean()
average_math
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
# SCHOOL SUMMARY - Average Reading Score
average_reading = grouped_schools["reading_score"].mean()
average_reading
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
# SCHOOL SUMMARY - Passing Math Score
passing_math = school_data_complete.loc[school_data_complete["math_score"] >= 70]
grouped_math = passing_math.groupby(['school_name'])
print(grouped_math)
grouped_math.count().head(15)
# Out:
# ...
#                        Student ID  student_name  gender  grade  reading_score  \
# school_name
# Bailey High School           3318          3318    3318   3318           3318
# Cabrera High School          1749          1749    1749   1749           1749
# Figueroa High School         1946          1946    1946   1946           1946
# Ford High School             1871          1871    1871   1871           1871
# Griffin High School          1371          1371    1371   1371           1371
# Hernandez High School        3094          3094    3094   3094           3094
# Holden High School            395           395     395    395            395
# Huang High School            1916          1916    1916   1916           1916
# Johnson High School          3145          3145    3145   3145           3145
# Pena High School              910           910     910    910            910
# Rodriguez High School        2654          2654    2654   2654           2654
# ...

# %%
# SCHOOL SUMMARY - Passing Reading Score
passing_reading = school_data_complete.loc[school_data_complete["reading_score"] >= 70]
grouped_reading = passing_reading.groupby(['school_name'])
print(grouped_reading)
grouped_reading.count().head(15)
# Out:
# ...
#                        Student ID  student_name  gender  grade  reading_score  \
# school_name
# Bailey High School           4077          4077    4077   4077           4077
# Cabrera High School          1803          1803    1803   1803           1803
# Figueroa High School         2381          2381    2381   2381           2381
# Ford High School             2172          2172    2172   2172           2172
# Griffin High School          1426          1426    1426   1426           1426
# Hernandez High School        3748          3748    3748   3748           3748
# Holden High School            411           411     411    411            411
# Huang High School            2372          2372    2372   2372           2372
# Johnson High School          3867          3867    3867   3867           3867
# Pena High School              923           923     923    923            923
# Rodriguez High School        3208          3208    3208   3208           3208
# ...

# %%
# SCHOOL SUMMARY - Percentage Passing Math
percent_math = [66.68, 94.13, 65.99, 68.31, 93.39, 66.75, 92.51, 65.68, 66.06, 94.59, 66.37, 93.87, 93.27, 93.87, 93.33]

# %%
# SCHOOL SUMMARY - Percentage Passing Reading
percent_reading = [81.93, 97.04, 80.74, 79.30, 97.14, 80.86, 96.25, 81.32, 81.22, 95.95, 80.22, 95.85, 97.31, 96.54, 96.61]

# %%
# SCHOOL SUMMARY - Passing Both
passing_both = school_data_complete.loc[(school_data_complete["math_score"] >= 70) & (school_data_complete["reading_score"] >= 70)]
grouped_both = passing_both.groupby(['school_name'])
print(grouped_both)
grouped_both.count().head(15)
# Out:
# ...
#                        Student ID  student_name  gender  grade  reading_score  \
# school_name
# Bailey High School           2719          2719    2719   2719           2719
# Cabrera High School          1697          1697    1697   1697           1697
# Figueroa High School         1569          1569    1569   1569           1569
# Ford High School             1487          1487    1487   1487           1487
# Griffin High School          1330          1330    1330   1330           1330
# Hernandez High School        2481          2481    2481   2481           2481
# Holden High School            381           381     381    381            381
# Huang High School            1561          1561    1561   1561           1561
# Johnson High School          2549          2549    2549   2549           2549
# Pena High School              871           871     871    871            871
# Rodriguez High School        2119          2119    2119   2119           2119
# ...

# %%
# SCHOOL SUMMARY - Percentage Passing Both
percent_both = [54.64, 91.33, 53.20, 54.29, 90.60, 53.53, 89.23, 53.51, 53.53, 90.54, 52.99, 89.89, 90.95, 90.58, 90.33]

# %%
# SCHOOL SUMMARY - Data Frame
summary_df = pd.DataFrame({"School Type": school_type, "Total Students": total_students, "Total School Budget": budget, "Per Student Budget": per_student, "Average Math Score": average_math, "Average Reading Score": average_reading, "% Passing Math": percent_math, "% Passing Reading": percent_reading, "% Overall Passing": percent_both})
summary_df.head(15)
# Out:
#                       School Type  Total Students Total School Budget  \
# school_name
# Bailey High School       District            4976            $3124928
# Cabrera High School       Charter            1858            $1081356
# Figueroa High School     District            2949            $1884411
# Ford High School         District            2739            $1763916
# Griffin High School       Charter            1468              917500
# Hernandez High School    District            4635            $3022020
# Holden High School        Charter             427             $248087
# Huang High School        District            2917            $1910635
# Johnson High School      District            4761            $3094650
# Pena High School          Charter             962             $585858
# Rodriguez High School    District            3999            $2547363
# Shelton High School       Charter            1761            $1056600
# ...

# %%
# TOP PERFORMING SCHOOLS
top_df = summary_df.sort_values("% Overall Passing", ascending=False)
top_df.head(5)
# Out:
#                     School Type  Total Students Total School Budget  \
# school_name
# Cabrera High School     Charter            1858            $1081356
# Thomas High School      Charter            1635            $1043130
# Griffin High School     Charter            1468              917500
# Wilson High School      Charter            2283            $1319574
# Pena High School        Charter             962             $585858
#
#                     Per Student Budget  Average Math Score  \
# school_name
# Cabrera High School               $582           83.061895
# Thomas High School                $638           83.418349
# Griffin High School               $625           83.351499
# Wilson High School                $578           83.274201
# Pena High School                  $609           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# school_name
# ...

# %%
# BOTTOM PERFORMING SCHOOLS
bottom_df = summary_df.sort_values("% Overall Passing")
bottom_df.head(5)
# Out:
#                       School Type  Total Students Total School Budget  \
# school_name
# Rodriguez High School    District            3999            $2547363
# Figueroa High School     District            2949            $1884411
# Huang High School        District            2917            $1910635
# Hernandez High School    District            4635            $3022020
# Johnson High School      District            4761            $3094650
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Rodriguez High School               $637           76.842711
# Figueroa High School                $639           76.711767
# Huang High School                   $655           76.629414
# Hernandez High School               $652           77.289752
# Johnson High School                 $650           77.072464
#
#                        Average Reading Score  % Passing Math  \
# school_name
# Rodriguez High School              80.744686           66.37
# ...

# %%
# MATH AND READING SCORES BY GRADE
grouped = school_data_complete.groupby(["school_name", "grade"])
print(grouped)
grouped.mean()
# Out:
# ...
#                                Student ID  reading_score  math_score  \
# school_name           grade
# Bailey High School    10th   20365.058918      80.907183   76.996772
#                       11th   20345.148681      80.945643   77.515588
#                       12th   20386.724708      80.912451   76.492218
#                       9th    20344.481481      81.303155   77.083676
# Cabrera High School   10th   16909.487124      84.253219   83.154506
#                       11th   16955.047718      83.788382   82.765560
#                       12th   16924.570681      84.287958   83.277487
#                       9th    16969.634470      83.676136   83.094697
# Figueroa High School  10th    4332.703801      81.408912   76.539974
#                       11th    4424.478138      80.640339   76.884344
#                       12th    4414.922705      81.384863   77.151369
#                       9th     4397.878505      81.198598   76.403037
# ...

# %%
# SCORES BY SCHOOL SPENDING
bins = [0, 584, 631, 644, 680]
group_labels = ["$0-$584", "$585-$630", "$631-$644", "$645-$680"]

# %%
pd.cut(summary_df["Per Student Budget"], bins, labels=group_labels).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-ac3cacdcb4a7> in <module>
# ----> 1 pd.cut(summary_df["Per Student Budget"], bins, labels=group_labels).head()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     273             raise ValueError("bins must increase monotonically.")
#     274
# --> 275     fac, bins = _bins_to_cuts(
#     276         x,
#     277         bins,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     407
#     408     side = "left" if right else "right"
# --> 409     ids = ensure_int64(bins.searchsorted(x, side=side))
#     410
#     411     if include_lowest:
#
# ...

# %%
summary_df["Spending Group"] = pd.cut(summary_df["Per Student Budget"], bins, labels=group_labels)
summary_df.head()

# %%
student_group = summary_df.groupby("Spending Group")
student_group[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()

# %%
# SCORES BY SCHOOL SIZE
bins = [0, 999, 1999, 4999]
group_labels = ["Small <1000", "Medium 1000-1999", "Large 2000-5000"]

# %%
pd.cut(summary_df["Total Students"], bins, labels=group_labels).head()
# Out:
# school_name
# Bailey High School       Large 2000-5000
# Cabrera High School     Medium 1000-1999
# Figueroa High School     Large 2000-5000
# Ford High School         Large 2000-5000
# Griffin High School     Medium 1000-1999
# Name: Total Students, dtype: category
# Categories (3, object): ['Small <1000' < 'Medium 1000-1999' < 'Large 2000-5000']

# %%
summary_df["TS_Group"] = pd.cut(summary_df["Total Students"], bins, labels=group_labels)
summary_df.head()
# Out:
#                      School Type  Total Students Total School Budget  \
# school_name
# Bailey High School      District            4976            $3124928
# Cabrera High School      Charter            1858            $1081356
# Figueroa High School    District            2949            $1884411
# Ford High School        District            2739            $1763916
# Griffin High School      Charter            1468              917500
#
#                      Per Student Budget  Average Math Score  \
# school_name
# Bailey High School                 $628           77.048432
# Cabrera High School                $582           83.061895
# Figueroa High School               $639           76.711767
# Ford High School                   $644           77.102592
# Griffin High School                $625           83.351499
#
#                       Average Reading Score  % Passing Math  \
# school_name
# Bailey High School                81.033963           66.68
# ...

# %%
student_group = summary_df.groupby("TS_Group")
student_group[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()
# Out:
#                   Average Math Score  Average Reading Score  % Passing Math  \
# TS_Group
# Small <1000                83.821598              83.929843        93.55000
# Medium 1000-1999           83.374684              83.864438        93.59800
# Large 2000-5000            77.746417              81.344493        69.96375
#
#                   % Passing Reading  % Overall Passing
# TS_Group
# Small <1000                96.10000           89.88500
# Medium 1000-1999           96.79000           90.62000
# Large 2000-5000            82.76625           58.28375

# %%
# SCORES BY SCHOOL TYPE
bins = ["Charter", "District"]
group_labels = ["Charter", "District"]

# %%
pd.cut(summary_df["School Type"], bins, labels=group_labels).head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-0c115926c2c8> in <module>
# ----> 1 pd.cut(summary_df["School Type"], bins, labels=group_labels).head()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     270
#     271         # GH 26045: cast to float64 to avoid an overflow
# --> 272         if (np.diff(bins.astype("float64")) < 0).any():
#     273             raise ValueError("bins must increase monotonically.")
#     274
#
# ValueError: could not convert string to float: 'Charter'

# %%
summary_df["ST_Group"] = pd.cut(summary_df["School Type"], bins, labels=group_labels)
summary_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-be0acd3e1ae3> in <module>
# ----> 1 summary_df["ST_Group"] = pd.cut(summary_df["School Type"], bins, labels=group_labels)
#       2 summary_df.head()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     270
#     271         # GH 26045: cast to float64 to avoid an overflow
# --> 272         if (np.diff(bins.astype("float64")) < 0).any():
#     273             raise ValueError("bins must increase monotonically.")
#     274
#
# ValueError: could not convert string to float: 'Charter'

# %%
student_group = summary_df.groupby("ST_Group")
student_group[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-133-1d4921542af5> in <module>
# ----> 1 student_group = summary_df.groupby("ST_Group")
#       2 student_group[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...
